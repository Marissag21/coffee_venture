# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('ankita_updated/coffee_clean_final.csv')
df.head()
# Out:
#    Unnamed: 0                                        title  rating  \
# 0           0                      Bolivia Manantial Gesha    93.0
# 1           1  Yellow Pacamara Carbonic Maceration Nanolot    92.0
# 2           2                   Ethiopia Gera Genji Challa    94.0
# 3           3                 Yirgacheffe Mengesha Natural    94.0
# 4           4           Tropical Summer Colombia La Sierra    93.0
#
#    acidity_structure  aftertaste  aroma  body  flavor  \
# 0                9.0         8.0    9.0   8.0     9.0
# 1                8.0         8.0    9.0   8.0     9.0
# 2                9.0         8.0    9.0   9.0     9.0
# 3                9.0         8.0    9.0   9.0     9.0
# 4                9.0         8.0    9.0   8.0     9.0
#
#                                     blind_assessment  \
# 0  Richly aromatic, floral-toned. Magnolia, cocoa...
# 1  Crisply sweet-savory. White peach, hop flowers...
# 2  Delicately aromatic, complex. Lilac, cocoa nib...
# 3  High-toned, fruit-driven. Boysenberry, pear, c...
# 4  Fruit-driven, crisply chocolaty. Goji berry, d...
#
#                                     coffee_origin  \
# 0                               Caranavi, Bolivia
# 1             Matagalpa growing region, Nicaragua
# 2  Agaro Gera, Jimma Zone, Oromia State, Ethiopia
# 3   Yirgacheffe growing region, southern Ethiopia
# 4           La Sierra, Cauca Department, Colombia
#
#                                                notes   roast_level  \
# 0  Produced by Angel Mamani Chambi, entirely of t...  Medium-Light
# 1  Produced by Benjamin Weiner at Finca Idealista...  Medium-Light
# 2  Ethiopia coffees like this one are largely pro...  Medium-Light
# 3  Produced at Mengesha Farm from selections of i...  Medium-Light
# 4  Produced by smallholding farmers from trees of...  Medium-Light
#
#            city        state  usd_per_oz
# 0         Floyd     Virginia        2.50
# 1     Cleveland         Ohio       13.33
# 2     San Diego   California        2.33
# 3      Glendale   California        1.71
# 4  Harrisonburg     Virginia        2.37

# %%
df["usd_per_oz"].max()
# Out:
# 255697506.81

# %%
sorted_df = df.sort_values('usd_per_oz', ascending=False)
sorted_df.head(30)
# Out:
#       Unnamed: 0                                              title  rating  \
# 1189        1189                            Alamendah Patuha Coffee    94.0
# 1190        1190                            Ceri Ceri Meriah Coffee    94.0
# 2062        2062                                  Sumatra Afro-Gayo    92.0
# 1999        1999           Kenya AA Top Nyeri Tekangu Tegu Microlot    94.0
# 1890        1890               Ethiopia Yirgacheffe Natural Grade 1    92.0
# 2019        2019                         Ethiopia Guji Zone Natural    94.0
# 2066        2066                              Washed Ethiopia Worka    92.0
# 1801        1801                              Nicaragua Finca Libre    92.0
# 933          933                   GW01 Finca Sophia Olympus Geisha    98.0
# 1086        1086                              Taiwan Songyue Geisha    94.0
# 678          678                           Brazil Gauriroba Natural    94.0
# 825          825  SÖT Coffee Roaster Colombia Wush Wush Dynamic ...    96.0
# 1087        1087                          Colombia Cauca El Paraiso    96.0
# 605          605                       Ethiopia Guji Hambela Dabaye    91.0
# 606          606                         Ethiopia Guji Uraga Yabitu    92.0
# 604          604                  Ethiopia Dry-Process Guji Hambela    90.0
# 603          603                   Ethiopia Dry-Process Benti Nenka    90.0
# 1007        1007                               Guatemala Acatenango    93.0
# 1006        1006                                  Kenya Gachatha AB    93.0
# 648          648                                       Rwanda Simbi    93.0
# 159          159  Ecuador COE 1st place Arashi Typica Mejorado W...    96.0
# 465          465                            Ecuador Finca Cruz Loma    95.0
# 1449        1449           Panama Boquete Torre Lot #1 Geisha Honey    94.0
# 28            28  Panama Hacienda La Esmeralda Super Mario Geish...    95.0
# 949          949      Ethiopia COE 2nd place Washed Sidamo Rumudamo    94.0
# 1207        1207  Panama Hacienda La Esmeralda Geisha Natural Sp...    94.0
# 315          315               Panama El Burro Estate Natural Gesha    95.0
# 1652        1652                      Gesha Village Natural Lot #19    94.0
# 146          146              Taiwan Natural Alishan Zhuo-Wu Geisha    95.0
# 1949        1949                                       Yemen Haraaz    92.0
#
#       acidity_structure  aftertaste  aroma  body  flavor  \
# 1189                9.0         8.0    9.0   9.0     9.0
# 1190                9.0         8.0    9.0   9.0     9.0
# 2062                8.0         8.0    9.0   8.0     9.0
# 1999                9.0         8.0    9.0   9.0     9.0
# 1890                8.0         8.0    9.0   8.0     9.0
# 2019                9.0         8.0    9.0   9.0     9.0
# 2066                8.0         8.0    9.0   9.0     8.0
# 1801                8.0         8.0    8.0   9.0     9.0
# 933                10.0         9.0   10.0   9.0    10.0
# 1086                9.0         8.0    9.0   9.0     9.0
# 678                 9.0         8.0    9.0   9.0     9.0
# 825                 9.0         8.0   10.0   9.0    10.0
# 1087                9.0         9.0    9.0   9.0    10.0
# 605                 8.0         8.0    8.0   8.0     9.0
# 606                 9.0         8.0    8.0   8.0     9.0
# 604                 8.0         8.0    8.0   8.0     8.0
# 603                 8.0         7.0    8.0   8.0     9.0
# 1007                8.0         8.0    9.0   9.0     9.0
# 1006                9.0         8.0    9.0   8.0     9.0
# 648                 8.0         8.0    9.0   9.0     9.0
# 159                 9.0         9.0    9.0   9.0    10.0
# 465                 9.0         9.0    9.0   9.0     9.0
# 1449                9.0         8.0    9.0   9.0     9.0
# 28                  9.0         9.0    9.0   9.0     9.0
# 949                 9.0         8.0    9.0   9.0     9.0
# 1207                9.0         8.0    9.0   9.0     9.0
# 315                 9.0         9.0    9.0   9.0     9.0
# 1652                9.0         8.0    9.0   9.0     9.0
# 146                 9.0         9.0    9.0   9.0     9.0
# 1949                8.0         8.0    9.0   8.0     9.0
#
#                                        blind_assessment  \
# 1189  Richly sweet-savory. Concord grape, freesia, c...
# 1190  Complex, multi-layered, crisply sweet-tart. Ap...
# 2062  Crisply sweet, high-toned. Maple syrup, sandal...
# 1999  Delicately intricate; deeply sweet and pungent...
# 1890  Delicate, fruit-toned. Raspberry, dark chocola...
# 2019  Delicate, richly spice- and fruit-toned. Ripe ...
# 2066  High-toned, sweetly tart. Maple syrup, pistach...
# 1801  Crisp, roundly and sweetly zesty. Cedar, lemon...
# 933   Graceful, polished, exquisitely floral. Lavend...
# 1086  Delicate, sweetly tart, richly aromatic. Lemon...
# 678   Citrusy-bright, juicy-sweet, spice-toned. Pink...
# 825   Savory-sweet, intensely aromatic and flavor-sa...
# 1087  Lyrically sweet, juicy, elegantly bright. Stra...
# 605   Gently fruit-toned, sweetly tart. Plum, cocoa ...
# 606   Citrusy and sweetly herbaceous, cocoa-toned. C...
# 604   Balanced, delicate, floral-toned. Dogwood flow...
# 603   Delicate, crisply sweet. Prairie flowers, fres...
# 1007  Crisply sweet, gently resonant. Freesia, apric...
# 465   Produced at Finca Cruz Loma from the Typica Me...   Medium-Dark
# 1449  Produced from the trees of the rare Ethiopia-d...         Light
# 28    Coffee from trees of the botanical variety Gei...  Medium-Light
# 949   Produced entirely from trees of the admired 74...  Medium-Light
# 1207  Coffee from trees of the botanical variety Gei...  Medium-Light
# 315   El Burro Estate is an award-winning coffee far...  Medium-Light
# 1652  This coffee tied for the fourth-highest rating...  Medium-Light
# 146   Produced by Hsu Ting-Yeh of Zhuo-Wu Farm in th...  Medium-Light
# 1949  Haraz (also Haraaz, other spellings) is a cele...  Medium-Light
#
#                          city         state    usd_per_oz
# 1189                  Jakarta     Indonesia  2.556975e+08
# 1190                  Jakarta     Indonesia  2.556975e+08
# 2062                  Jakarta     Indonesia  2.045580e+08
# 1999                    Seoul   South Korea  3.579573e+06
# 1890  Paju City (Gyeonggi-do)   South Korea  2.637580e+06
# 2019                  Daejeon   South Korea  2.449181e+06
# 2066                  Daejeon   South Korea  2.449181e+06
# 1801                Yongin-Si   South Korea  1.657907e+06
# 933                     Yilan        Taiwan  2.177783e+05
# 1086                    Osaka         Japan  2.013460e+05
# 678                     Osaka         Japan  1.136384e+05
# 825                     Osaka         Japan  6.406463e+04
# 1087                    Osaka         Japan  6.025126e+04
# 605                   Tochigi         Japan  4.881115e+04
# 606                   Tochigi         Japan  4.881115e+04
# 604                   Tochigi         Japan  4.881115e+04
# 603                   Tochigi         Japan  4.881115e+04
# 1007                  Tochigi         Japan  4.614179e+04
# 1006                  Tochigi         Japan  4.614179e+04
# 648                   Tochigi         Japan  4.004039e+04
# 159                     Yilan        Taiwan  3.484453e+04
# 465                   Taoyuan        Taiwan  3.136008e+04
# 1449                Kaohsiung        Taiwan  2.177783e+04
# 28                     Taipei        Taiwan  1.814819e+04
# 949                   Chia-Yi        Taiwan  1.524448e+04
# 1207                   Taipei        Taiwan  1.219559e+04
# 315                  Chiya-Yi        Taiwan  1.067114e+04
# 1652                    Yilan        Taiwan  1.045336e+04
# 146                   Chia-Yi        Taiwan  1.045336e+04
# 1949                  Hsinchu        Taiwan  9.977510e+03

# %%
# Define the features and target variables
features = df[['acidity_structure', 'aroma', 'body', 'flavor', 'usd_per_oz']]
target = df['roast_level']

# %%
# Split data into training and testing sets
train_data, test_data, train_target, test_target = train_test_split(
    features, target, test_size=0.2, random_state=42)

# %%
# Train decision tree model
decision_tree = DecisionTreeClassifier(random_state=42)
decision_tree.fit(train_data, train_target)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Train k-neighbors model
k_neighbors = KNeighborsClassifier(n_neighbors=5)
k_neighbors.fit(train_data, train_target)
# Out:
# KNeighborsClassifier()

# %%
# Evaluate accuracy of models on test set
decision_tree_accuracy = accuracy_score(test_target, decision_tree.predict(test_data))
k_neighbors_accuracy = accuracy_score(test_target, k_neighbors.predict(test_data))

# %%
print(f"Decision tree accuracy: {decision_tree_accuracy}")
print(f"K-neighbors accuracy: {k_neighbors_accuracy}")
# Out:
# Decision tree accuracy: 0.6033254156769596
# K-neighbors accuracy: 0.6389548693586699

# %%
def predict_roast(acidity, aroma, body, flavor, price):
    input_data = [[acidity, aroma, body, flavor, price]]
    roast_dtc = decision_tree.predict(input_data)[0]
    roast_knc = k_neighbors.predict(input_data)[0]
    return roast_dtc, roast_knc
