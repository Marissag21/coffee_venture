# %%
#import dependencies
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

# %%
#read the CSV == source - https://www.kaggle.com/datasets/patkle/coffeereviewcom-over-7000-ratings-and-reviews
csv_data = "reviews_feb_2023.csv"
coffee_df = pd.read_csv(csv_data)
coffee_df.head()
# Out:
#                                          title rating  acidity_structure  \
# 0                      Bolivia Manantial Gesha     93                9.0
# 1  Yellow Pacamara Carbonic Maceration Nanolot     92                8.0
# 2                   Ethiopia Gera Genji Challa     94                9.0
# 3                 Yirgacheffe Mengesha Natural     94                9.0
# 4           Tropical Summer Colombia La Sierra     93                9.0
#
#    aftertaste aroma body flavor with_milk agtron  \
# 0         8.0     9    8      9       NaN  60/78
# 1         8.0     9    8      9       NaN  60/78
# 2         8.0     9    9      9       NaN  59/77
# 3         8.0     9    9      9       NaN  60/77
# 4         8.0     9    8      9       NaN  60/77
#
#                                     blind_assessment  \
# 0  Richly aromatic, floral-toned. Magnolia, cocoa...
# 1  Crisply sweet-savory. White peach, hop flowers...
# 2  Delicately aromatic, complex. Lilac, cocoa nib...
# 3  High-toned, fruit-driven. Boysenberry, pear, c...
# 4  Fruit-driven, crisply chocolaty. Goji berry, d...
#
#                                          bottom_line  \
# 0  This washed Boliva Gesha has all the aromatics...
# 1  A carbonic-macerated Yellow Pacamara grown in ...
# 2  A nuanced, multilayered washed Ethiopia cup wi...
# 3  A fruit medley in a cup — think boysenberry an...
# 4  An experimentally processed Colombia, sweetly ...
#
#                                     coffee_origin          est_price  \
# 0                               Caranavi, Bolivia   $30.00/12 ounces
# 1             Matagalpa growing region, Nicaragua  $160.00/12 ounces
# 2  Agaro Gera, Jimma Zone, Oromia State, Ethiopia   $28.00/12 ounces
# 3   Yirgacheffe growing region, southern Ethiopia   $20.50/12 ounces
# 4           La Sierra, Cauca Department, Colombia    $18.99/8 ounces
#
#                                                notes review_date  \
# 0  Produced by Angel Mamani Chambi, entirely of t...      Jan-23
# 1  Produced by Benjamin Weiner at Finca Idealista...      Dec-22
# 2  Ethiopia coffees like this one are largely pro...      Dec-22
# 3  Produced at Mengesha Farm from selections of i...      Nov-22
# 4  Produced by smallholding farmers from trees of...      Nov-22
#
#     roast_level                     roaster        roaster_location  \
# 0  Medium-Light  Red Rooster Coffee Roaster         Floyd, Virginia
# 1  Medium-Light     Eccentricity Coffee Co.         Cleveland, Ohio
# 2  Medium-Light               Mostra Coffee   San Diego, California
# 3  Medium-Light               Regent Coffee    Glendale, California
# 4  Medium-Light        Merge Coffee Company  Harrisonburg, Virginia
#
#                                                  url
# 0  https://www.coffeereview.com/review/bolivia-ma...
# 1  https://www.coffeereview.com/review/brix-break...
# 2  https://www.coffeereview.com/review/ethiopia-g...
# 3  https://www.coffeereview.com/review/yirgacheff...
# 4  https://www.coffeereview.com/review/tropical-s...

# %%
#check for null values
coffee_df.isnull().sum()
# Out:
# title                   0
# rating                  0
# acidity_structure    4875
# aftertaste            872
# aroma                  50
# body                   11
# flavor                 16
# with_milk            6044
# agtron                  0
# blind_assessment        1
# bottom_line          4080
# coffee_origin         505
# est_price            2039
# notes                   8
# review_date             0
# roast_level           374
# roaster                 0
# roaster_location        3
# url                     0
# dtype: int64

# %%
#drop the unneccessary columns 'with_milk','agtron','roaster','url' and high null value cols which are 'acidity_structure', 'bottom_line'
coffee1_df = coffee_df.drop(columns=['with_milk','agtron','roaster','url','acidity_structure', 'bottom_line', "review_date"])
coffee1_df.head()
coffee1_df.index
# Out:
# RangeIndex(start=0, stop=7041, step=1)

# %%
#check if cols are dropped and detect which cols have null values
coffee1_df.isnull().sum()
# Out:
# title                  0
# rating                 0
# aftertaste           872
# aroma                 50
# body                  11
# flavor                16
# blind_assessment       1
# coffee_origin        505
# est_price           2039
# notes                  8
# roast_level          374
# roaster_location       3
# dtype: int64

# %%
#removed columns and null values to show 4905 rows × 13 columns with no null values
coffee2_df = coffee1_df.dropna(subset=['title', 'aftertaste', 'aroma', 'body', 'flavor', 'blind_assessment',
                                       'coffee_origin', 'est_price', 'notes', 'roast_level', 'roaster_location'])
coffee2_df = coffee2_df.drop_duplicates()
coffee2_df.reset_index(drop=True)
# Out:
#                                             title rating  aftertaste aroma  \
# 0                         Bolivia Manantial Gesha     93         8.0     9
# 1     Yellow Pacamara Carbonic Maceration Nanolot     92         8.0     9
# 2                      Ethiopia Gera Genji Challa     94         8.0     9
# 3                    Yirgacheffe Mengesha Natural     94         8.0     9
# 4              Tropical Summer Colombia La Sierra     93         8.0     9
# ...                                           ...    ...         ...   ...
# 4899                     Ethiopia Kemgin Espresso     92         8.0     9
# 4900                           Kenya AA Gandurine     93         8.0     9
# 4901                        Honduras David Mancia     94         9.0     9
# 4902                                 Doug E Fresh     90         8.0     9
# 4903                             Tangletown Blend     89         8.0     8
#
#      body flavor                                   blind_assessment  \
# 0       8      9  Richly aromatic, floral-toned. Magnolia, cocoa...
# 1       8      9  Crisply sweet-savory. White peach, hop flowers...
# 2       9      9  Delicately aromatic, complex. Lilac, cocoa nib...
# 3       9      9  High-toned, fruit-driven. Boysenberry, pear, c...
# 4       8      9  Fruit-driven, crisply chocolaty. Goji berry, d...
# ...   ...    ...                                                ...
# 4899    7      9  Evaluated as espresso. In the small cup exhila...
# 4900    8      9  Balanced in aroma and cup. Floral tones are co...
# 4901    8      9  Deep, rich and pungent in aroma and cup. Round...
# 4902    7      8  Gently and richly charred cedar, dark chocolat...
# 4903    7      8  Lively citrus and berry in the aroma with hint...
#
#                                        coffee_origin  \
# 0                                  Caranavi, Bolivia
# 1                Matagalpa growing region, Nicaragua
# 2     Agaro Gera, Jimma Zone, Oromia State, Ethiopia
# 3      Yirgacheffe growing region, southern Ethiopia
# 4              La Sierra, Cauca Department, Colombia
# ...                                              ...
# 4899                                Western Ethiopia
# 4900                            South-central Kenya.
# 4901             Santa Barbara Department, Honduras.
# 4902                                  Not disclosed.
# 4903                                Central America.
#
#                         est_price  \
# 0                $30.00/12 ounces
# 1               $160.00/12 ounces
# 2                $28.00/12 ounces
# 3                $20.50/12 ounces
# 4                 $18.99/8 ounces
# ...                           ...
# 4899  $27.00/500 grams (17.6 oz.)
# 4900             $19.45/16 ounces
# 4901   $10.50/250 grams (8.8 oz.)
# 4902             $13.99/16 ounces
# 4903             $11.95/16 ounces
#
#                                                   notes   roast_level  \
# 0     Produced by Angel Mamani Chambi, entirely of t...  Medium-Light
# 1     Produced by Benjamin Weiner at Finca Idealista...  Medium-Light
# 2     Ethiopia coffees like this one are largely pro...  Medium-Light
# 3     Produced at Mengesha Farm from selections of i...  Medium-Light
# 4     Produced by smallholding farmers from trees of...  Medium-Light
# ...                                                 ...           ...
# 4899  A special selection of hand sorted coffee from...        Medium
# 4900  Despite grower discontent and sporadic social ...        Medium
# 4901  Produced on the two hectare farm of David Manc...  Medium-Light
# 4902  Founded in 1993 near the famous Winter Park sk...     Very Dark
# 4903  Available in a 16-ounce valve bag at $11.95. C...         Light
#
#             roaster_location
# 0            Floyd, Virginia
# 1            Cleveland, Ohio
# 2      San Diego, California
# 3       Glendale, California
# 4     Harrisonburg, Virginia
# ...                      ...
# 4899        Portland, Oregon
# 4900      Lee, Massachusetts
# 4901        Portland, Oregon
# 4902        Fraser, Colorado
# 4903     Seattle, Washington
#
# [4904 rows x 12 columns]

# %%
#check for datatypes for any null values and datatypes
display(coffee2_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4904 entries, 0 to 5258
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             4904 non-null   object
#  1   rating            4904 non-null   object
#  2   aftertaste        4904 non-null   float64
#  3   aroma             4904 non-null   object
#  4   body              4904 non-null   object
#  5   flavor            4904 non-null   object
#  6   blind_assessment  4904 non-null   object
#  7   coffee_origin     4904 non-null   object
#  8   est_price         4904 non-null   object
#  9   notes             4904 non-null   object
#  10  roast_level       4904 non-null   object
#  11  roaster_location  4904 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 498.1+ KB
# None

# %%
coffee3_df = coffee2_df.astype({"title":"string", "rating": float, "aroma": float, "body": float, "flavor": float, "blind_assessment": "string", "coffee_origin": "string", "est_price": "string", "notes": "string", "roast_level": "string", "roaster_location":"string"})
display(coffee3_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4904 entries, 0 to 5258
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             4904 non-null   string
#  1   rating            4904 non-null   float64
#  2   aftertaste        4904 non-null   float64
#  3   aroma             4904 non-null   float64
#  4   body              4904 non-null   float64
#  5   flavor            4904 non-null   float64
#  6   blind_assessment  4904 non-null   string
#  7   coffee_origin     4904 non-null   string
#  8   est_price         4904 non-null   string
#  9   notes             4904 non-null   string
#  10  roast_level       4904 non-null   string
#  11  roaster_location  4904 non-null   string
# dtypes: float64(5), string(7)
# memory usage: 498.1 KB
# None

# %%
coffee3_df = coffee2_df['roaster_location'].str.split(',', n=1, expand=True)
coffee3_df.columns=['city', 'country']
coffee3_df.reset_index(drop=True)
# Out:
#               city         country
# 0            Floyd        Virginia
# 1        Cleveland            Ohio
# 2        San Diego      California
# 3         Glendale      California
# 4     Harrisonburg        Virginia
# ...            ...             ...
# 4899      Portland          Oregon
# 4900           Lee   Massachusetts
# 4901      Portland          Oregon
# 4902        Fraser        Colorado
# 4903       Seattle      Washington
#
# [4904 rows x 2 columns]

# %%
coffee4_df = coffee2_df.merge(coffee3_df, how='inner')
coffee4_df
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# c:\Users\ankit\OneDrive\Desktop\coffee\coffee_venture\ankita_coffee_data.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ankit/OneDrive/Desktop/coffee/coffee_venture/ankita_coffee_data.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> coffee4_df = coffee2_df.merge(coffee3_df, how='inner')
#       <a href='vscode-notebook-cell:/c%3A/Users/ankit/OneDrive/Desktop/coffee/coffee_venture/ankita_coffee_data.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> coffee4_df
#
# File c:\Users\ankit\anaconda3\lib\site-packages\pandas\core\frame.py:9345, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9326 @Substitution("")
#    9327 @Appender(_merge_doc, indents=2)
#    9328 def merge(
#    (...)
#    9341     validate: str | None = None,
#    9342 ) -> DataFrame:
#    9343     from pandas.core.reshape.merge import merge
# -> 9345     return merge(
#    9346         self,
#    9347         right,
#    9348         how=how,
#    9349         on=on,
#    9350         left_on=left_on,
#    9351         right_on=right_on,
#    9352         left_index=left_index,
#    9353         right_index=right_index,
#    9354         sort=sort,
#    9355         suffixes=suffixes,
#    9356         copy=copy,
#    9357         indicator=indicator,
#    9358         validate=validate,
#    9359     )
#
# File c:\Users\ankit\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
#     117         suffixes=suffixes,
#     118         copy=copy,
#     119         indicator=indicator,
#     120         validate=validate,
#     121     )
#     122     return op.get_result()
#
# File c:\Users\ankit\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:682, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     678     # stacklevel chosen to be correct when this is reached via pd.merge
#     679     # (and not DataFrame.join)
#     680     warnings.warn(msg, FutureWarning, stacklevel=find_stack_level())
# --> 682 self._validate_specification()
#     684 cross_col = None
#     685 if self.how == "cross":
#
# File c:\Users\ankit\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:1349, in _MergeOperation._validate_specification(self)
#    1347 common_cols = left_cols.intersection(right_cols)
#    1348 if len(common_cols) == 0:
# -> 1349     raise MergeError(
#    1350         "No common columns to perform merge on. "
#    1351         f"Merge options: left_on={self.left_on}, "
#    1352         f"right_on={self.right_on}, "
#    1353         f"left_index={self.left_index}, "
#    1354         f"right_index={self.right_index}"
#    1355     )
#    1356 if (
#    1357     not left_cols.join(common_cols, how="inner").is_unique
#    1358     or not right_cols.join(common_cols, how="inner").is_unique
#    1359 ):
#    1360     raise MergeError(f"Data columns not unique: {repr(common_cols)}")
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
# regex = r(?P<City>[^,]+)\s*,\s*(?P<State>[^\s]+)\s+(?P<Country>[^,]+)
# coffee_origin_df = coffee2_df['coffee_origin'].str.extract(regex)

# %%
# !pip install forex_python
from forex_python.converter import CurrencyRates
# Out:
# Requirement already satisfied: forex_python in c:\users\ankit\anaconda3\lib\site-packages (1.8)
# Requirement already satisfied: simplejson in c:\users\ankit\anaconda3\lib\site-packages (from forex_python) (3.19.1)
# Requirement already satisfied: requests in c:\users\ankit\anaconda3\lib\site-packages (from forex_python) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ankit\anaconda3\lib\site-packages (from requests->forex_python) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ankit\anaconda3\lib\site-packages (from requests->forex_python) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from requests->forex_python) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ankit\anaconda3\lib\site-packages (from requests->forex_python) (2021.10.8)
